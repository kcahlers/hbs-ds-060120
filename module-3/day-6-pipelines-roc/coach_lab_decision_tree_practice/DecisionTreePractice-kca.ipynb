# %% [markdown]
# # Decision Tree Practice

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import roc_auc_score, plot_roc_curve
from sklearn import tree

# %%
# Grabbing our data, then exploring it a bit
# Data source: https://www.kaggle.com/ronitf/heart-disease-uci
df = pd.read_csv("heart.csv")

# %% [markdown]
# # EDA

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
X = df.drop(columns = 'target')

# %%
y=df.target

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=.2, random_state=7, stratify=y)
#stratify makes sure target equally represented as % between train and test

# %%
y_train.value_counts(normalize=True)
# Out:
# 1    0.545455
# 0    0.454545
# Name: target, dtype: float64

# %%
y_test.value_counts(normalize=True)
# Out:
# 1    0.540984
# 0    0.459016
# Name: target, dtype: float64

# %%
X_train.head()
#only look at head here because me as human dont want to be biased by test
#whatsoever
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 170   56    1   2       130   256    1        0      142      1      0.6
# 124   39    0   2        94   199    0        1      179      0      0.0
# 134   41    0   1       126   306    0        1      163      0      0.0
# 28    65    0   2       140   417    1        0      157      0      0.8
# 208   49    1   2       120   188    0        1      139      0      2.0
#
#      slope  ca  thal
# 170      1   1     1
# 124      2   0     2
# 134      2   0     2
# 28       2   1     2
# 208      1   3     3

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 242 entries, 170 to 11
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       242 non-null    int64
#  1   sex       242 non-null    int64
#  2   cp        242 non-null    int64
#  3   trestbps  242 non-null    int64
#  4   chol      242 non-null    int64
#  5   fbs       242 non-null    int64
#  6   restecg   242 non-null    int64
#  7   thalach   242 non-null    int64
#  8   exang     242 non-null    int64
#  9   oldpeak   242 non-null    float64
#  10  slope     242 non-null    int64
#  11  ca        242 non-null    int64
#  12  thal      242 non-null    int64
# dtypes: float64(1), int64(12)
# memory usage: 26.5 KB

# %%
X_train.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  242.000000  242.000000  242.000000  242.000000  242.000000  242.000000
# mean    54.086777    0.685950    1.016529  131.677686  242.590909    0.173554
# std      9.217334    0.465098    1.054400   18.005861   47.020191    0.379510
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.000000    0.000000    0.000000  120.000000  210.250000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  239.000000    0.000000
# 75%     60.750000    1.000000    2.000000  140.000000  269.000000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  417.000000    1.000000
#
#           restecg     thalach       exang     oldpeak      slope          ca  \
# count  242.000000  242.000000  242.000000  242.000000  242.00000  242.000000
# mean     0.570248  149.785124    0.338843    1.016116    1.42562    0.780992
# std      0.528467   23.236724    0.474297    1.153503    0.61503    1.053334
# min      0.000000   71.000000    0.000000    0.000000    0.00000    0.000000
# 25%      0.000000  134.500000    0.000000    0.000000    1.00000    0.000000
# 50%      1.000000  152.000000    0.000000    0.650000    1.00000    0.000000
# 75%      1.000000  169.000000    1.000000    1.600000    2.00000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.00000    4.000000
#
#              thal
# count  242.000000
# mean     2.297521
# std      0.633041
# min      0.000000
# 25%      2.000000
# 50%      2.000000
# 75%      3.000000
# max      3.000000

# %%
for column in X_train.columns:
    print(X_train[column].value_counts())
    #trying to see which are categorical - how to visualize
# Out:
# 58    18
# 54    15
# 57    14
# 52    11
# 44    10
# 59     9
# 51     9
# 56     9
# 43     8
# 63     8
# 62     8
# 60     8
# 64     7
# 65     7
# 53     7
# 42     7
# 66     6
# 45     6
# 41     6
# 67     6
# 61     6
# 49     5
# 46     5
# 47     5
# 48     4
# 39     4
# 55     4
# 50     3
# 71     3
# 38     3
# 69     3
# 68     3
# 40     3
# 35     3
# 37     2
# 34     2
# 77     1
# 76     1
# 70     1
# 74     1
# 29     1
# Name: age, dtype: int64
# 1    166
# 0     76
# Name: sex, dtype: int64
# 0    112
# 2     76
# 1     34
# 3     20
# Name: cp, dtype: int64
# 130    28
# 120    28
# 140    25
# 110    15
# 150    14
# 138    11
# 128    10
# 112     9
# 125     8
# 132     7
# 160     7
# 118     7
# 124     6
# 108     6
# 134     5
# 152     5
# 100     4
# 145     3
# 126     3
# 170     3
# 105     3
# 136     3
# 180     3
# 135     3
# 115     2
# 94      2
# 142     2
# 178     2
# 146     2
# 129     1
# 114     1
# 102     1
# 174     1
# 172     1
# 165     1
# 164     1
# 117     1
# 156     1
# 192     1
# 155     1
# 148     1
# 122     1
# 123     1
# 144     1
# 200     1
# Name: trestbps, dtype: int64
# 234    6
# 204    6
# 197    5
# 269    4
# 226    4
#       ..
# 311    1
# 210    1
# 242    1
# 306    1
# 232    1
# Name: chol, Length: 134, dtype: int64
# 0    200
# 1     42
# Name: fbs, dtype: int64
# 1    130
# 0    108
# 2      4
# Name: restecg, dtype: int64
# 162    9
# 173    8
# 152    7
# 163    7
# 144    7
#       ..
# 195    1
# 137    1
# 134    1
# 129    1
# 71     1
# Name: thalach, Length: 87, dtype: int64
# 0    160
# 1     82
# Name: exang, dtype: int64
# 0.0    81
# 1.2    13
# 0.8    12
# 0.6    11
# 1.0    11
# 1.6    10
# 1.4    10
# 0.2     8
# 1.8     8
# 2.0     7
# 0.4     7
# 0.1     7
# 2.8     5
# 0.5     5
# 1.9     4
# 3.0     4
# 3.6     4
# 1.5     3
# 2.2     3
# 2.6     3
# 3.4     3
# 2.5     2
# 1.1     2
# 0.3     2
# 4.2     2
# 0.9     2
# 2.3     2
# 4.0     2
# 4.4     1
# 6.2     1
# 2.1     1
# 0.7     1
# 2.4     1
# 3.5     1
# 3.1     1
# 3.2     1
# 3.8     1
# Name: oldpeak, dtype: int64
# 2    119
# 1    107
# 0     16
# Name: slope, dtype: int64
# 0    134
# 1     54
# 2     32
# 3     17
# 4      5
# Name: ca, dtype: int64
# 2    130
# 3     93
# 1     17
# 0      2
# Name: thal, dtype: int64

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Logistic Regression
#
# ### Preprocessing
#
# What kind of preprocessing steps are there?
# - Imputing
# - Scaling
# - Encoding

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline, Pipeline

# %% [markdown]
# ### Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
# Lets set up a Logistic Regression Pipeline
encoder = OneHotEncoder(drop='first')

catvar = ['restecg', 'slope', 'ca', 'thal']
catvarid = [X_train.columns.tolist().index(column) for column in catvar]
catvarid
pipe_lr = make_pipeline(SimpleImputer(),
                        ColumnTransformer([('encoder', encoder, catvarid)],
                                          remainder='passthrough', 
                                          sparse_threshold=0), 
                        StandardScaler(), 
                        LogisticRegression())


pipe_lr2 = make_pipeline(SimpleImputer(),
                       ColumnTransformer([('encoder', encoder, catvarid)],
                                        remainder='passthrough',
                                        sparse_threshold=0),
                       StandardScaler(),
                       LogisticRegression())

pipe_lr.steps
# Out:
# [('simpleimputer', SimpleImputer()),
#  ('columntransformer',
#   ColumnTransformer(remainder='passthrough', sparse_threshold=0,
#                     transformers=[('encoder', OneHotEncoder(drop='first'),
#                                    [6, 10, 11, 12])])),
#  ('standardscaler', StandardScaler()),
#  ('logisticregression', LogisticRegression())]

# %%
pipe_lr.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                 ('columntransformer',
#                  ColumnTransformer(remainder='passthrough', sparse_threshold=0,
#                                    transformers=[('encoder',
#                                                   OneHotEncoder(drop='first'),
#                                                   [6, 10, 11, 12])])),
#                 ('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression())])

# %%
# Lets fit the LogReg on our training and calculate our roc_auc_scores
train_pred = pipe_lr.predict_proba(X_train)
test_pred = pipe_lr.predict_proba(X_test)

# %% [markdown]
# How'd we do?

# %%
train_score = roc_auc_score(y_train, train_pred[:,1])
#all rows second column
test_score = roc_auc_score(y_test, test_pred[:,1])

# %%
train_pred
#list of lists with 2 elements
# Out:
# array([[7.37686007e-01, 2.62313993e-01],
#        [2.34996341e-03, 9.97650037e-01],
#        [2.05177846e-02, 9.79482215e-01],
#        [1.77061749e-01, 8.22938251e-01],
#        [8.32260186e-01, 1.67739814e-01],
#        [9.68389893e-01, 3.16101067e-02],
#        [9.99158927e-01, 8.41073318e-04],
#        [6.14806484e-02, 9.38519352e-01],
#        [4.11694338e-01, 5.88305662e-01],
#        [6.70472414e-02, 9.32952759e-01],
#        [3.35014147e-01, 6.64985853e-01],
#        [2.38880095e-01, 7.61119905e-01],
#        [6.80272935e-03, 9.93197271e-01],
#        [1.74642715e-02, 9.82535728e-01],
#        [9.80551245e-01, 1.94487551e-02],
#        [2.06084675e-01, 7.93915325e-01],
#        [8.18584198e-01, 1.81415802e-01],
#        [9.98654118e-01, 1.34588192e-03],
#        [9.94601519e-01, 5.39848073e-03],
#        [1.81429794e-01, 8.18570206e-01],
#        [8.59447116e-01, 1.40552884e-01],
#        [2.96421438e-02, 9.70357856e-01],
#        [9.42793686e-01, 5.72063137e-02],
#        [1.44337282e-02, 9.85566272e-01],
#        [9.55964481e-01, 4.40355188e-02],
#        [5.17923727e-01, 4.82076273e-01],
#        [2.11912414e-02, 9.78808759e-01],
#        [8.32796697e-01, 1.67203303e-01],
#        [1.29150325e-02, 9.87084968e-01],
#        [5.08700979e-03, 9.94912990e-01],
#        [9.94923199e-01, 5.07680076e-03],
#        [9.99571418e-01, 4.28581934e-04],
#        [2.13323559e-01, 7.86676441e-01],
#        [4.86875244e-01, 5.13124756e-01],
#        [2.65447126e-03, 9.97345529e-01],
#        [9.94214350e-01, 5.78564970e-03],
#        [9.70497121e-01, 2.95028793e-02],
#        [9.80634046e-01, 1.93659544e-02],
#        [1.31144478e-01, 8.68855522e-01],
#        [1.12800217e-01, 8.87199783e-01],
#        [9.77869478e-01, 2.21305223e-02],
#        [4.10755182e-01, 5.89244818e-01],
#        [7.45101687e-01, 2.54898313e-01],
#        [4.29419695e-02, 9.57058030e-01],
#        [9.75161647e-01, 2.48383533e-02],
#        [9.85867427e-01, 1.41325725e-02],
#        [6.35939491e-01, 3.64060509e-01],
#        [2.27041165e-01, 7.72958835e-01],
#        [8.96019628e-01, 1.03980372e-01],
#        [9.97893935e-01, 2.10606512e-03],
#        [8.20279473e-01, 1.79720527e-01],
#        [2.78033105e-02, 9.72196689e-01],
#        [3.30821730e-01, 6.69178270e-01],
#        [3.79416382e-02, 9.62058362e-01],
#        [6.44217490e-01, 3.55782510e-01],
#        [1.39466998e-01, 8.60533002e-01],
#        [2.00962936e-01, 7.99037064e-01],
#        [9.80407853e-01, 1.95921469e-02],
#        [3.06334967e-01, 6.93665033e-01],
#        [2.16597321e-01, 7.83402679e-01],
#        [5.16009477e-01, 4.83990523e-01],
#        [4.30601814e-02, 9.56939819e-01],
#        [9.92364008e-01, 7.63599248e-03],
#        [1.39783087e-02, 9.86021691e-01],
#        [3.44257480e-01, 6.55742520e-01],
#        [5.14317361e-01, 4.85682639e-01],
#        [2.13853118e-01, 7.86146882e-01],
#        [9.99074500e-01, 9.25500324e-04],
#        [5.55531208e-03, 9.94444688e-01],
#        [5.03173596e-03, 9.94968264e-01],
#        [6.41690097e-01, 3.58309903e-01],
#        [2.94354786e-01, 7.05645214e-01],
#        [1.42658663e-02, 9.85734134e-01],
#        [9.72529604e-01, 2.74703955e-02],
#        [2.86163600e-01, 7.13836400e-01],
#        [7.36941674e-01, 2.63058326e-01],
#        [1.50124316e-01, 8.49875684e-01],
#        [5.28290895e-02, 9.47170911e-01],
#        [7.40524826e-01, 2.59475174e-01],
#        [2.92098507e-02, 9.70790149e-01],
#        [9.84753171e-01, 1.52468285e-02],
#        [4.61348698e-02, 9.53865130e-01],
#        [1.46266306e-02, 9.85373369e-01],
#        [3.74396621e-01, 6.25603379e-01],
#        [1.56377843e-01, 8.43622157e-01],
#        [1.78697850e-01, 8.21302150e-01],
#        [4.97367972e-01, 5.02632028e-01],
#        [1.20551758e-01, 8.79448242e-01],
#        [8.35455876e-01, 1.64544124e-01],
#        [3.09062595e-01, 6.90937405e-01],
#        [9.39267145e-01, 6.07328552e-02],
#        [2.20000442e-01, 7.79999558e-01],
#        [9.98058906e-01, 1.94109375e-03],
#        [9.99567855e-01, 4.32145203e-04],
#        [3.99714184e-01, 6.00285816e-01],
#        [4.18814004e-01, 5.81185996e-01],
#        [7.22437367e-03, 9.92775626e-01],
#        [4.32871261e-01, 5.67128739e-01],
#        [3.23022740e-02, 9.67697726e-01],
#        [1.17047395e-01, 8.82952605e-01],
#        [9.90434867e-01, 9.56513298e-03],
#        [4.50880819e-01, 5.49119181e-01],
#        [7.75254797e-02, 9.22474520e-01],
#        [5.22493720e-01, 4.77506280e-01],
#        [5.10146342e-02, 9.48985366e-01],
#        [9.77531579e-01, 2.24684206e-02],
#        [9.95155788e-01, 4.84421222e-03],
#        [9.87775202e-01, 1.22247980e-02],
#        [9.79682675e-01, 2.03173246e-02],
#        [4.34022812e-03, 9.95659772e-01],
#        [8.61631523e-03, 9.91383685e-01]])

# %%
print(f"Train ROC AUC score: {train_score}")
print(f"Test ROC AUC score: {test_score}")

#overfit
# Out:
# Train ROC AUC score: 0.9495179063360881
# Test ROC AUC score: 0.8831168831168832

# %% [markdown]
# ## Decision Trees

# %% [markdown]
# #### let's do a basic decision tree with just the default values

# %%
from sklearn.tree import DecisionTreeClassifier
# Fit the model and lets see the tree
dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
plt.figure(figsize=(30,30))
tree.plot_tree(dt)
# Out:
# [Text(1024.7884615384614, 1556.6727272727271, 'X[2] <= 0.5\ngini = 0.496\nsamples = 242\nvalue = [110, 132]'),
#  Text(633.1153846153845, 1408.418181818182, 'X[11] <= 0.5\ngini = 0.366\nsamples = 112\nvalue = [85, 27]'),
#  Text(364.8461538461538, 1260.1636363636362, 'X[8] <= 0.5\ngini = 0.5\nsamples = 49\nvalue = [24, 25]'),
#  Text(171.69230769230768, 1111.909090909091, 'X[12] <= 2.5\ngini = 0.365\nsamples = 25\nvalue = [6, 19]'),
#  Text
5\ngini = 0.463\nsamples = 11\nvalue = [7, 4]'),
#  Text(1373.5384615384614, 370.63636363636374, 'X[11] <= 0.5\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(1330.6153846153845, 222.38181818181806, 'X[4] <= 256.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(1287.6923076923076, 74.12727272727284, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(1373.5384615384614, 74.12727272727284, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1416.4615384615383, 222.38181818181806, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(1459.3846153846152, 370.63636363636374, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(1545.230769230769, 667.1454545454545, 'X[1] <= 0.5\ngini = 0.165\nsamples = 22\nvalue = [2, 20]'),
#  Text(1502.3076923076922, 518.890909090909, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(1588.153846153846, 518.890909090909, 'X[4] <= 290.0\ngini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(1545.230769230769, 370.63636363636374, 'X[12] <= 2.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(1502.3076923076922, 222.38181818181806, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(1588.153846153846, 222.38181818181806, 'X[0] <= 65.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(1545.230769230769, 74.12727272727284, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(1631.0769230769229, 74.12727272727284, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1631.0769230769229, 370.63636363636374, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1373.5384615384614, 1111.909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(1502.3076923076922, 1260.1636363636362, 'X[10] <= 0.5\ngini = 0.426\nsamples = 13\nvalue = [9, 4]'),
#  Text(1459.3846153846152, 1111.909090909091, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(1545.230769230769, 1111.909090909091, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]')]

# %%
#gini between 0 and 0.5 - if 0 perfect above is WAYYY overfit

# %%
# Lets calculate the roc_auc_score
train_pred = dt.predict_proba(X_train)
test_pred = dt.predict_proba(X_test)

# %%
train_score = roc_auc_score(y_train,train_pred[:,1])
test_score = roc_auc_score(y_test,test_pred[:,1])
print(f"Train ROC AUC score: {train_score}")
print(f"Test ROC AUC score: {test_score}")
#WAYYYY overfit
# Out:
# Train ROC AUC score: 1.0
# Test ROC AUC score: 0.7207792207792209

# %%
dt.get_depth()
# Out:
# 10

# %% [markdown]
# #### A simple decision tree with a single split

# %%
# lets set up the Decision Tree with a single split
dt_1 = DecisionTreeClassifier(max_depth = 1)

dt_1.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
# Visualizing the single-split decision tree
plt.figure(figsize=(10,10))
tree.plot_tree(dt_1)
# Out:
# [Text(279.0, 407.70000000000005, 'X[2] <= 0.5\ngini = 0.496\nsamples = 242\nvalue = [110, 132]'),
#  Text(139.5, 135.89999999999998, 'gini = 0.366\nsamples = 112\nvalue = [85, 27]'),
#  Text(418.5, 135.89999999999998, 'gini = 0.311\nsamples = 130\nvalue = [25, 105]')]

# %%
# Lets calculate the roc_auc_score
train_pred = dt_1.predict_proba(X_train)
test_pred = dt_1.predict_proba(X_test)
train_score = roc_auc_score(y_train,train_pred[:,1])
test_score = roc_auc_score(y_test,test_pred[:,1])
print(f"Train ROC AUC score: {train_score}")
print(f"Test ROC AUC score: {test_score}")
# Out:
# Train ROC AUC score: 0.784090909090909
# Test ROC AUC score: 0.6574675324675324

# %% [markdown]
# #### Try something Random!

# %%
# Okay - time to change things!
# Replace None with relevant code
dt_2 = DecisionTreeClassifier(max_depth= 5, criterion='entropy', 
                              min_samples_split=10)

dt_2.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_split=10)

# %%
# Visualizing the decision tree
plt.figure(figsize=(20,20))
tree.plot_tree(dt_2)
# Out:
# [Text(658.44, 996.6, 'X[2] <= 0.5\nentropy = 0.994\nsamples = 242\nvalue = [110, 132]'),
#  Text(401.76, 815.4000000000001, 'X[11] <= 0.5\nentropy = 0.797\nsamples = 112\nvalue = [85, 27]'),
#  Text(223.2, 634.2, 'X[8] <= 0.5\nentropy = 1.0\nsamples = 49\nvalue = [24, 25]'),
#  Text(89.28, 453.0, 'X[4] <= 215.0\nentropy = 0.795\nsamples = 25\nvalue = [6, 19]'),
#  Text(44.64, 271.79999999999995, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(133.92000000000002, 271.79999999999995, 'X[12] <= 2.5\nentropy = 0.937\nsamples = 17\nvalue = [6, 11]'),
#  Text(89.28, 90.59999999999991, 'entropy = 0.65\nsamples = 12\nvalue = [2, 10]'),
#  Text(178.56, 90.59999999999991, 'entropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(357.12, 453.0, 'X[9] <= 1.55\nentropy = 0.811\nsamples = 24\nvalue = [18, 6]'),
#  Text(312.48, 271.79999999999995, 'X[7] <= 162.0\nentropy = 0.996\nsamples = 13\nvalue = [7, 6]'),
#  Text(267.84000000000003, 90.59999999999991, 'entropy = 0.946\nsamples = 11\nvalue = [7, 4]'),
#  Text(357.12, 90.59999999999991, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(401.76, 271.79999999999995, 'entropy = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(580.32, 634.2, 'X[9] <= 0.4\nentropy = 0.203\nsamples = 63\nvalue = [61, 2]'),
#  Text(535.6800000000001, 453.0, 'X[7] <= 106.5\nentropy = 0.567\nsamples = 15\nvalue = [13, 2]'),
#  Text(491.04, 271.79999999999995, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(580.32, 271.79999999999995, 'X[3] <= 109.0\nentropy = 0.371\nsamples = 14\nvalue = [13, 1]'),
#  Text(535.6800000000001, 90.59999999999991, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(624.96, 90.59999999999991, 'entropy = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(624.96, 453.0, 'entropy = 0.0\nsamples = 48\nvalue = [48, 0]'),
#  Text(915.12, 815.4000000000001, 'X[9] <= 1.95\nentropy = 0.706\nsamples = 130\nvalue = [25, 105]'),
#  Text(803.52, 634.2, 'X[0] <= 55.5\nentropy = 0.576\nsamples = 117\nvalue = [16, 101]'),
#  Text(714.24, 453.0, 'X[7] <= 135.0\nentropy = 0.31\nsamples = 72\nvalue = [4, 68]'),
#  Text(669.6, 271.79999999999995, 'entropy = 0.971\nsamples = 5\nvalue = [2, 3]'),
#  Text(758.88, 271.79999999999995, 'X[3] <= 182.0\nentropy = 0.194\nsamples = 67\nvalue = [2, 65]'),
#  Text(714.24, 90.59999999999991, 'entropy = 0.113\nsamples = 66\nvalue = [1, 65]'),
#  Text(803.52, 90.59999999999991, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(892.8, 453.0, 'X[3] <= 122.0\nentropy = 0.837\nsamples = 45\nvalue = [12, 33]'),
#  Text(848.16, 271.79999999999995, 'entropy = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(937.44, 271.79999999999995, 'X[3] <= 139.0\nentropy = 0.918\nsamples = 36\nvalue = [12, 24]'),
#  Text(892.8, 90.59999999999991, 'entropy = 0.918\nsamples = 12\nvalue = [8, 4]'),
#  Text(982.08, 90.59999999999991, 'entropy = 0.65\nsamples = 24\nvalue = [4, 20]'),
#  Text(1026.72, 634.2, 'X[10] <= 0.5\nentropy = 0.89\nsamples = 13\nvalue = [9, 4]'),
#  Text(982.08, 453.0, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(1071.3600000000001, 453.0, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]')]

# %%
# Lets calculate the roc_auc_score
train_preds = dt_2.predict_proba(X_train)
test_preds = dt_2.predict_proba(X_test)

train_score = roc_auc_score(y_train, train_preds[:,1])
test_score = roc_auc_score(y_test, test_preds[:,1])

print(f"Train ROC-AUC: {train_score}")
print(f"Test ROC-AUC: {test_score}")
# Out:
# Train ROC-AUC: 0.9758264462809917
# Test ROC-AUC: 0.737012987012987

# %% [markdown]
# ## [GridSearch](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html)
#
# Lets start by taking a look at the documentation

# %%
grid_params = {
    'max_depth':[3,4,5,6,7],
    'max_features' : ['sqrt','log2'],
    'class_weight' : [None, 'balanced'],
    'criterion': ['gini','entropy']  
} #different arguments for estimator in question
#ex max depth -- the grid params are in reference to decision tree
#cv in reference to grid search 
#this is why you have to keep them separate, even if you want to iterate 
#over a list of cv (e.g. cv= [2,3,4])
grid_search = GridSearchCV(dt,grid_params, cv= 4, scoring='roc_auc')
grid_search.fit(X_train,y_train)
#CV = cross validation
#estimator = decision tree
# Out:
# GridSearchCV(cv=4, estimator=DecisionTreeClassifier(),
#              param_grid={'class_weight': [None, 'balanced'],
#                          'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 4, 5, 6, 7],
#                          'max_features': ['sqrt', 'log2']},
#              scoring='roc_auc')

# %%
grid_search.best_estimator_
# Out:
# DecisionTreeClassifier(class_weight='balanced', criterion='entropy',
#                        max_depth=3, max_features='log2')

# %%
dt_grid=grid_search.best_estimator_

dt_grid.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', criterion='entropy',
#                        max_depth=3, max_features='log2')

# %%
tree.plot_tree(dt_grid)
# Out:
# [Text(167.4, 190.26, 'X[12] <= 2.5\nentropy = 1.0\nsamples = 242\nvalue = [121.0, 121.0]'),
#  Text(83.7, 135.9, 'X[0] <= 54.5\nentropy = 0.905\nsamples = 149\nvalue = [46.2, 98.083]'),
#  Text(41.85, 81.53999999999999, 'X[12] <= 1.5\nentropy = 0.627\nsamples = 82\nvalue = [12.1, 65.083]'),
#  Text(20.925, 27.180000000000007, 'entropy = 0.94\nsamples = 5\nvalue = [3.3, 1.833]'),
#  Text(62.775000000000006, 27.180000000000007, 'entropy = 0.535\nsamples = 77\nvalue = [8.8, 63.25]'),
#  Text(125.55000000000001, 81.53999999999999, 'X[10] <= 1.5\nentropy = 1.0\nsamples = 67\nvalue = [34.1, 33.0]'),
#  Text(104.625, 27.180000000000007, 'entropy = 0.894\nsamples = 37\nvalue = [26.4, 11.917]'),
#  Text(146.475, 27.180000000000007, 'entropy = 0.838\nsamples = 30\nvalue = [7.7, 21.083]'),
#  Text(251.10000000000002, 135.9, 'X[9] <= 0.7\nentropy = 0.786\nsamples = 93\nvalue = [74.8, 22.917]'),
#  Text(209.25, 81.53999999999999, 'X[11] <= 0.5\nentropy = 0.999\nsamples = 32\nvalue = [15.4, 16.5]'),
#  Text(188.32500000000002, 27.180000000000007, 'entropy = 0.9\nsamples = 18\nvalue = [5.5, 11.917]'),
#  Text(230.175, 27.180000000000007, 'entropy = 0.9\nsamples = 14\nvalue = [9.9, 4.583]'),
#  Text(292.95, 81.53999999999999, 'X[4] <= 198.5\nentropy = 0.461\nsamples = 61\nvalue = [59.4, 6.417]'),
#  Text(272.02500000000003, 27.180000000000007, 'entropy = 0.0\nsamples = 9\nvalue = [9.9, 0.0]'),
#  Text(313.875, 27.180000000000007, 'entropy = 0.514\nsamples = 52\nvalue = [49.5, 6.417]')]

# %% [markdown]
# # Vizualizing all the models scores

# %%
# Visualizing the ROCs for the models we've done
fig, ax = plt.subplots()
plot_roc_curve(pipe_lr, X_test, y_test, name="Baseline Log Reg", ax=ax)
plot_roc_curve(dt, X_test, y_test, name="Default DT", ax=ax)
plot_roc_curve(dt_1, X_test, y_test, name="DT with Max Depth = 1", ax=ax)
#plot_roc_curve(dt_2, X_test, y_test, name="DT with Max Depth = 2", ax=ax)
plot_roc_curve(dt_2, X_test, y_test, name="DT with Hyper Parameters", ax=ax)
plot_roc_curve(dt_grid, X_test, y_test, name="DT after Grid Search", ax=ax)

ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
         label='Chance', alpha=.8)
plt.title("Receiver Operating Characteristic Curves\n(Evaluated on Test Set)")
ax.legend()
plt.show()

# %% [markdown]
# What can we learn from this visualization? Which is the best model - and how could you tell without looking at the scores?
#
# - Baseline is still best - from both the visualization (closest to the '1' corner) and from the score
