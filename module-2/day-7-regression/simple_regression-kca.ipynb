# %% [markdown]
# # Introduction to Simple Linear Regression
#
#
# ## Learning Objectives and outcomes
#
# - Introduction of linear regression in a simple setting.
#
# - Basic assumptions of the model.
#
# - Terminology - 'intercept', 'coefficient'.
#
# - The Least Squares method.
#
# - Implement linear regression in sklearn and statsmodels

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !head data/Advertising.csv
# Out:
# "","TV","Radio","Newspaper","Sales"
# "1",230.1,37.8,69.2,22.1
# "2",44.5,39.3,45.1,10.4
# "3",17.2,45.9,69.3,9.3
# "4",151.5,41.3,58.5,18.5
# "5",180.8,10.8,58.4,12.9
# "6",8.7,48.9,75,7.2
# "7",57.5,32.8,23.5,11.8
# "8",120.2,19.6,11.6,13.2
# "9",8.6,2.1,1,4.8

# %%
# read data to a dataframe
data = pd.read_csv('data/Advertising.csv',
                   index_col=0)[['TV', 'Sales']]

print(data.shape)
data.head()
# Out:
# (200, 2)
#       TV  Sales
# 1  230.1   22.1
# 2   44.5   10.4
# 3   17.2    9.3
# 4  151.5   18.5
# 5  180.8   12.9

# %% [markdown]
# Note that TV is dollars in thousands and sales are in thousands of units too.

# %%
# plot data
data.plot(kind='scatter', x='TV', y='Sales')
plt.show()

# %%
import seaborn as sns
sns.lmplot(x='TV',y='Sales',data=data)

# %%
# Let's discuss very briefly the notation we will be using

# We usually represent independent variables (input variables) with X:

X = data.TV

# similarly the dependent variable with y:

y = data.Sales

# %%
display(data.head(3))

print(X[3], y[3])
# Out:
#       TV  Sales
# 1  230.1   22.1
# 2   44.5   10.4
# 3   17.2    9.3
# 17.2 9.3

# %% [markdown]
# Recall that a line equation on the plane can be written as:
#
# $$ y = m\cdot x + b$$

# %%
# this function will make a y prediction for y (sales)
# given x (TV) and fixed m (slope) and b (intercept)

def predict_y(m=1, x=2, b=1):
    return m*x + b

# %% [markdown]
# __Your Turn__
#
# Suppose m = 0.04 and b = 7:
#
# - Find y if x = 230.1
#
# - Find y if x = 44.5
#
# - Find y if x = 17.2

# %%
predict_y(x=230.1, m=.04, b=7)
# Out:
# 16.204

# %%
predict_y(x=44.5, m=.04, b=7)
# Out:
# 8.78

# %%
X = data.head(3).TV

# %%
X
# Out:
# 1    230.1
# 2     44.5
# 3     17.2
# Name: TV, dtype: float64

# %%
predict_y(m=0.04, x=X, b=7)
#array of predicted y values for X array
# Out:
# 1    16.204
# 2     8.780
# 3     7.688
# Name: TV, dtype: float64

# %%
def draw_line(X, y, intercept=7, slope=0.04, xlabel='Tv Advertisements',
              ylabel='Sales', title='A prediction for Sales'):
    """
    draws a line with given intercept and slope together with given data.
    parameters:
    X: array
    y: array
    intercept: float, preferably between 5 and 9 in this case
    slope: float, preferably between 0.02 and 0.08
    xlabel: str, label of the x-axis in the figure.
    ylabel: str, label of the y-axis in the figure.
    return: a figure with data and a regression line with given intercept and slope.
    """
    # find the predicted values. These points lie on the line with
    # given slope and intecept
    y_pred = intercept + slope * X

    # create a new figure and set the figure size
    plt.figure(figsize=(10, 8))

    # plot data points as scatter
    plt.scatter(x=X, y=y)

    # plot the prediction line
    plt.plot(X, y_pred, c='r', label='Regression Line')

    plt.ylim(bottom=1)

    # set labels
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

    # set the title of the figure
    plt.title(title)

    plt.legend()
    plt.show()
    return

# %%
tv = data.TV.values
sales = data.Sales.values
draw_line(tv, sales, intercept=7, slope=0.05)

# %% [markdown]
# ## Assumptions
#
# * Assume $\mbox{Sales} \approx \mbox{TV}$  linearly.
#
# * There is an initial value (baseline) of the Sales.
#
# * Data might not be fit on a line but the errors are random.

# %%
# Sometimes linearity assumption is too strict

expr_x = np.linspace(-5, 5, 100)
y = expr_x**2 + 2
draw_line(expr_x, y, intercept=10, slope=3,
          xlabel='',
          ylabel='',
          title='Regression line for quadratic data')

# %%
X = np.linspace(-1, 1, 100)

# %%
errors = np.random.normal(loc=0, scale=1, size=100)

# %%
plt.hist(errors)
# Out:
# (array([ 3.,  6., 10., 12., 16., 23., 17.,  8.,  4.,  1.]),
#  array([-2.30102263, -1.81552929, -1.33003595, -0.84454261, -0.35904927,
#          0.12644407,  0.61193741,  1.09743075,  1.58292409,  2.06841743,
#          2.55391077]),
#  <a list of 10 Patch objects>)

# %%
plt.scatter(X, errors)
plt.hlines(y=0, xmin=-1, xmax=1)
plt.show()

# %% [markdown]
# ## Model  - Single Variable Case
#
# - In simple linear regression we assume that if we would have population of both X and y variables then we would see the following relation:
#
# $$ Y = \beta_{0} + \beta X + \epsilon$$
#
# - $ \beta_{0}, \beta$ are parameters of the model and called the intercept and coefficient of the linear model respectively.
#
# - $\epsilon$ is the irreducible error term. Depend on the problem at hand we might assume that these errors are coming from measurement mistakes, personal beliefs, recording errors, etc.
#
# - Our goal is given samples from X and y, try to find estimates $\hat{\beta}_{0}$ and $\hat{\beta}_{1}$ for population parameters $\beta_{0}$ and  $\beta_{1}$
# - Once we find such estimates we can use them for future predictions: $\hat{\beta}_{0}$ and $\hat{\beta}_{1}$ we will make a prediction:
#
# $$ \hat{y}_{i} = \hat{\beta}_{0} + \hat{\beta}_{1} x_{1} $$
#
# <img src="visuals/best_fit.png" cap="Transformed dataset"  width='300'/>

# %% [markdown]
# ## Using Sklearn for simple linear regression
#
# - Fitting a regression model is very easy with python.
#
# - All we have to do is importing LinearRegression class from sklearn.linear_model module
#
# - For more details and examples of implementation you can check:
#
# [Sklearn Linear Regression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression)
#
# __Your Turn!__
#
# - Now using 'tv' and 'Sales' try to fit a linear model with sklearn. Find the corresponding intercept and slope values.

# %%
X = data.TV.values
#type numpy array
y = data.Sales.values

# %%
X.shape
#no columns, 1D
#how would you not have a column if you have 200 rows...? great q
# Out:
# (200,)

# %%
X = X.reshape(-1, 1)
#retuns same data with new shape
#-1 grabs last element (len of X)
X.shape
#now 2 columns
# Out:
# (200, 1)

# %%
X[:10]
#nested an array inside itself
# Out:
# array([[230.1],
#        [ 44.5],
#        [ 17.2],
#        [151.5],
#        [180.8],
#        [  8.7],
#        [ 57.5],
#        [120.2],
#        [  8.6],
#        [199.8]])

# %%
# import LinearRegression class
from sklearn.linear_model import LinearRegression

# %%
# instantiate the class
lr = LinearRegression()
#creating an instance of linear regression model
#completely empty
#why are we doing this? idk. my guess is shorthand

# check parameters

# %%
# now fit the data.  
print('Shape of X before reshape:', X.shape)
# Out:
# Shape of X before reshape: (200, 1)

# %%
# a reshape may be necessary
print('Shape of X after reshape:', X.shape)
# Out:
# Shape of X after reshape: (200, 1)

# %%
# when you fit model learns b0_hat and b1_hat
lr.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# now we can use fitted object to get model parameters 
lr.ceof_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-9b02ad5e9cdc> in <module>
#       1 # now we can use fitted object to get model parameters
# ----> 2 lr.ceof_
#
# AttributeError: 'LinearRegression' object has no attribute 'ceof_'

# %%
lr.intercept_
# Out:
# 7.032593549127693

# %% [markdown]
# ## How do we find an estimator? Least Squares method.
# <a name="least_squares">
# </a>
#
# __Q: How to find 'best' line?__
#
#
# <img src="visuals/errors.png" cap="Transformed dataset"  width='500'/>
#
#
#
# * Recall that we know actual values $y$ for the sales and for given coefficients $\beta_{0}, \beta_{1}$ we can make a prediction $\hat{y}$.
#
# * Error for each prediction $e_{i} = y_{i} - \hat{y_{i}}$

# %% [markdown]
# ### Residual sum of squares (RSS)
#
#
# $$RSS = e_{1}^{2} + e_{2}^{2} + \cdots + e_{n}^{2}$$
#
# * Wait a minute! Why do we get the squares?
#
#
# The least square method minimizes the RSS.
#
# * Good news: The least square can be calculated exactly because it has a closed form:
#
# $$ \mbox{RSS} = (y_1 - \hat{b}_{0} -\hat{b}_{1}x_{1} )^{2} + (y_2 - \hat{b}_{0} -\hat{b}_{1}x_{2} )^{2} + \cdots + (y_n -\hat{b}_{0} -\hat{b}_{1}x_{n} )^{2}$$
#
# * Bad news: It requires derivatives and is complicated to derive. But no worries, python will take care of this step for us.
#
# $$ \hat{b}_{1} = \dfrac{\sum^{n}_{i=1} (x_i - \bar{x})(y_{i}-\bar{y})}{\sum^{n}_{i=1} (x_i - \bar{x})^{2}}$$
#
# and
#
# $$ \hat{b}_{0} = \bar{y} - \hat{b}_{1}\bar{x} $$
#
# - __Note:__ In the literature you might see some variants of RSS: Some of which are:
#
# $$ \mbox{Mean Squared Errors (MSE)} = \frac{1}{N} \mbox{RSS}$$
#
# $$ \mbox{Root Mean Squared Errors (RMSE)} = \sqrt{\frac{1}{N} \mbox{RSS}} $$
#
# [Least Squares Visualized](https://phet.colorado.edu/sims/html/least-squares-regression/latest/least-squares-regression_en.html)

# %% [markdown]
# __Your Turn!__ (Together)
#
# Write a function that for given X, y data it returns $\hat{b}_{0}$ and $\hat{b}_{1}$ and RSS for this data. Compare the results with sklearn's results.
#
# Reminder:
#
# $$ \hat{b}_{1} = \dfrac{\sum^{n}_{i=1} (x_i - \bar{x})(y_{i}-\bar{y})}{\sum^{n}_{i=1} (x_i - \bar{x})^{2}}$$

# %%
def least_squares(X, y):
    numerator = ((X-X.mean()) * (y-y.mean())).sum()
    denom =((X-X.mean()) ** 2).sum()
    #could also use np pow 
    b_1=numerator/denom
    b_0=y.mean() - b_1 *X.mean()
    rss = ((y - b_0-b_1*X) **2),sum() 
    return(b_0,b_1,rss)

# %%
X=X.reshape(-1)

# %%
X
# Out:
# array([230.1,  44.5,  17.2, 151.5, 180.8,   8.7,  57.5, 120.2,   8.6,
#        199.8,  66.1, 214.7,  23.8,  97.5, 204.1, 195.4,  67.8, 281.4,
#         69.2, 147.3, 218.4, 237.4,  13.2, 228.3,  62.3, 262.9, 142.9,
#        240.1, 248.8,  70.6, 292.9, 112.9,  97.2, 265.6,  95.7, 290.7,
#        266.9,  74.7,  43.1, 228. , 202.5, 177. , 293.6, 206.9,  25.1,
#        175.1,  89.7, 239.9, 227.2,  66.9, 199.8, 100.4, 216.4, 182.6,
#        262.7, 198.9,   7.3, 136.2, 210.8, 210.7,  53.5, 261.3, 239.3,
#        102.7, 131.1,  69. ,  31.5, 139.3, 237.4, 216.8, 199.1, 109.8,
#         26.8, 129.4, 213.4,  16.9,  27.5, 120.5,   5.4, 116. ,  76.4,
#        239.8,  75.3,  68.4, 213.5, 193.2,  76.3, 110.7,  88.3, 109.8,
#        134.3,  28.6, 217.7, 250.9, 107.4, 163.3, 197.6, 184.9, 289.7,
#        135.2, 222.4, 296.4, 280.2, 187.9, 238.2, 137.9,  25. ,  90.4,
#         13.1, 255.4, 225.8, 241.7, 175.7, 209.6,  78.2,  75.1, 139.2,
#         76.4, 125.7,  19.4, 141.3,  18.8, 224. , 123.1, 229.5,  87.2,
#          7.8,  80.2, 220.3,  59.6,   0.7, 265.2,   8.4, 219.8,  36.9,
#         48.3,  25.6, 273.7,  43. , 184.9,  73.4, 193.7, 220.5, 104.6,
#         96.2, 140.3, 240.1, 243.2,  38. ,  44.7, 280.7, 121. , 197.6,
#        171.3, 187.8,   4.1,  93.9, 149.8,  11.7, 131.7, 172.5,  85.7,
#        188.4, 163.5, 117.2, 234.5,  17.9, 206.8, 215.4, 284.3,  50. ,
#        164.5,  19.6, 168.4, 222.4, 276.9, 248.4, 170.2, 276.7, 165.6,
#        156.6, 218.5,  56.2, 287.6, 253.8, 205. , 139.5, 191.1, 286. ,
#         18.7,  39.5,  75.5,  17.2, 166.8, 149.7,  38.2,  94.2, 177. ,
#        283.6, 232.1])

# %%
X.mean()
# Out:
# 147.0425

# %%
(X-X.mean()) *(y-y.mean())
# Out:
# array([ 6.70896956e+02,  3.71460206e+02,  6.13181206e+02,  1.99584563e+01,
#        -3.78927938e+01,  9.43841706e+02,  1.99008206e+02,  2.20779563e+01,
#         1.27678596e+03, -1.80562544e+02,  4.38910706e+02,  2.28513206e+02,
#         5.94336956e+02,  2.14147456e+02,  2.84003706e+02,  4.05114956e+02,
#         1.20646706e+02,  1.39429496e+03,  2.11926206e+02,  1.48706250e-01,
#         2.83824456e+02, -1.37569294e+02,  1.12728846e+03,  1.20057956e+02,
#         3.66299456e+02, -2.34321794e+02, -4.04929375e+00,  1.74715456e+02,
#         4.96322206e+02,  2.69268706e+02,  1.07606371e+03,  7.24674562e+01,
#         2.20428456e+02,  4.00427956e+02,  2.32196456e+02, -1.75621294e+02,
#         1.36367871e+03, -4.90120437e+01,  4.07714456e+02,  6.05359706e+02,
#         1.42941706e+02,  9.21942063e+01,  9.78637706e+02, -6.71900438e+01,
#         6.73427456e+02,  2.46204562e+01,  1.96254706e+02,  8.52199706e+02,
#         6.23224562e+01,  3.46415956e+02, -1.38356544e+02,  1.54969706e+02,
#         5.94913956e+02,  2.55213956e+02,  7.14474206e+02,  5.01850956e+02,
#         1.19095546e+03,  8.91795625e+00,  6.23388956e+02,  2.78660706e+02,
#         5.54005456e+02,  1.16285571e+03,  1.54761956e+02,  9.97706250e-01,
#        -6.34112937e+01,  3.68555706e+02,  5.22540956e+02,  4.81970625e+00,
#         4.40718706e+02,  5.77417706e+02,  2.22675956e+02,  6.04259563e+01,
#         6.27966456e+02,  5.33244562e+01,  1.97579456e+02,  6.92683456e+02,
#         8.51441456e+02, -4.71129375e+00,  1.23547671e+03,  9.38259562e+01,
#         1.57002956e+02, -1.59774794e+02,  1.95318956e+02,  3.32264563e+01,
#         5.10227456e+02,  5.43504562e+01,  1.43076706e+02, -7.18672937e+01,
#         6.59384563e+01, -9.97167937e+01,  3.59657062e+01,  7.96229706e+02,
#         3.79960706e+02,  8.49294706e+02,  9.99982062e+01,  4.67809563e+01,
#        -1.17419794e+02,  5.59344562e+01,  1.62308571e+03, -3.76295437e+01,
#        -1.75017794e+02,  1.46034296e+03,  1.03529956e+02,  2.76809562e+01,
#         6.08704206e+02, -4.73352937e+01,  8.32634956e+02,  3.01479706e+02,
#         1.16831346e+03,  6.26035456e+02, -4.90265438e+01,  7.36198706e+02,
#         2.22095625e+00,  1.17451706e+02, -3.97565437e+01,  1.02338206e+02,
#         1.42929563e+01,  3.26544956e+02, -4.00705437e+01,  9.47426456e+02,
#        -8.48454375e+00,  9.00582956e+02, -1.86429544e+02, -2.81922937e+01,
#         4.68152456e+02,  2.04810956e+02,  1.03352746e+03,  3.49084956e+02,
#         7.82206956e+02,  3.77970206e+02,  1.81793971e+03, -1.56263294e+02,
#         1.15385221e+03,  4.05804956e+02,  3.54934206e+02,  2.39203706e+02,
#         5.49223706e+02,  8.58421206e+02,  4.60127956e+02,  2.52793456e+02,
#         2.29948706e+02,  2.41569206e+02,  4.46437956e+02,  1.53747956e+02,
#         1.33334456e+02,  2.50989562e+01, -7.65397938e+01,  1.09403196e+03,
#         3.40485206e+02,  4.01438456e+02,  2.77673456e+02,  6.30879563e+01,
#         1.30311956e+02,  1.20741706e+02,  6.42949562e+01,  1.54699521e+03,
#        -6.78895437e+01, -1.08162938e+01,  9.09839956e+02,  1.72219563e+01,
#         9.61020625e+00,  4.43199562e+01,  3.62912062e+01,  6.54597063e+01,
#         6.33407062e+01, -1.85628544e+02,  7.77760706e+02, -1.08908044e+02,
#         2.10370206e+02,  1.34169206e+02,  5.45621456e+02,  8.33595625e+00,
#         8.18499456e+02, -4.96027938e+01, -1.90089294e+02,  1.68522571e+03,
#         6.26135956e+02, -5.37832938e+01, -2.88163794e+02, -2.63980438e+01,
#        -3.36662938e+01, -1.30231294e+02,  4.83509206e+02,  1.71163896e+03,
#         3.81924956e+02,  4.97130456e+02,  2.80769562e+01,  1.44398456e+02,
#         2.60892706e+02,  9.39787956e+02,  3.46555706e+02,  2.94933956e+02,
#         1.05464571e+03,  1.10197456e+02,  8.70995625e+00,  6.99040956e+02,
#         2.28411706e+02, -3.66230438e+01,  1.56733871e+03, -5.29482938e+01])

# %%
((X-X.mean()) *(y-y.mean())).sum()
# Out:
# 69727.64875

# %%
b_0,b_1, rss = least_squares(X, y)
b_0,b_1, rss
# returns b0, b1 and RSS
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-4aebba48078e> in <module>
# ----> 1 b_0,b_1, rss = least_squares(X, y)
#       2 b_0,b_1, rss
#       3 # returns b0, b1 and RSS
#
# <ipython-input-69-c154de9ce0e5> in least_squares(X, y)
#       5     b_1=numerator/denom
#       6     b_0=y.mean() - b_1 *X.mean()
# ----> 7     rss = ((y - b_0-b_1*X) **2),sum()
#       8     return(b_0,b_1,rss)
#
# TypeError: sum expected at least 1 arguments, got 0

# %% [markdown]
# Now use statsmodel or sklearn to compare results.

# %%
X = X.reshape(-1,1)

# %%
lr = LinearRegression()

lr.fit(X,y)
print(lr.intercept_, lr.coef_)
# Out:
# 7.032593549127693 [0.04753664]

# %%
# let's use draw_line again for the given estimates.

# %%
draw_line(X, y, intercept=b_0 , slope= b_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-b2ceb161657c> in <module>
# ----> 1 draw_line(X, y, intercept=b_0 , slope= b_1)
#
# NameError: name 'b_0' is not defined

# %% [markdown]
# ## Linear Regression with Statsmodel
#
# There is another library that we can use for linear models which is Statsmodel.
#
# - [check the documentation](http://www.statsmodels.org/devel/generated/statsmodels.regression.linear_model.OLS.html#statsmodels.regression.linear_model.OLS)
#
# - Now let's use statsmodel to fit a linear model to our data.

# %%
import statsmodels.api as sm

# %% [markdown]
# __Your Turn__
#
# - Try to use statsmodel library to fit a line to the advertising dataset.

# %%
data
